# %%
from RandomAccessBag import ImageBag
from place_recognizer.srv import place_recognizer
import numpy as np
import pickle
import rospy
from cv_bridge import CvBridge

bridge = CvBridge()
def runPlaceRecognizerImg(imageArray):
    msg = bridge.cv2_to_imgmsg(imageArray, "bgr8")
    server = rospy.ServiceProxy('place_recognizer', place_recognizer)
    placeResp = server(msg)
    return placeResp.keyframeId

trainImagesLoc=np.loadtxt('/media/sujiwo/PlaceRecognition/vls128-conv.image.csv')
queryImagesLoc=np.loadtxt('/media/sujiwo/PlaceRecognition/ouster64-conv.image.csv')

queryBag=ImageBag('/media/sujiwo/PlaceRecognition/ouster64-prep-4.bag', '/front_rgb/image_raw')

distanceThreshold = 15.0

print("Test Length: {}".format(len(queryBag)))
print("Train Length: {}".format(len(trainImagesLoc)))

queryResults={}
for ti in range(len(queryBag)):
    print("Testing: {}".format(ti))
    image = queryBag[ti]
    qres=runPlaceRecognizerImg(image)
    rights=0
    wrongs=0
    for u in qres:
        loc=trainImagesLoc[u,1:4]
        dist=np.linalg.norm(loc-queryImagesLoc[ti,1:4])
        if (dist<=distanceThreshold):
            rights +=1
        else:
            wrongs +=1
    print("--- {}: {} True, {} False".format(ti, rights, wrongs))
    queryResults[ti] = [rights, wrongs]

pickle.dump(queryResults, open("/media/sujiwo/PlaceRecognition/test-prep4.pickle", "wb"))
print("Done")
# Out:
# Test Length: 31215
# Train Length: 33230
# Testing: 0
# --- 0: 1 True, 14 False
# Testing: 1
# --- 1: 0 True, 15 False
# Testing: 2
# --- 2: 0 True, 15 False
# Testing: 3
# --- 3: 0 True, 15 False
# Testing: 4
# --- 4: 0 True, 15 False
# Testing: 5
# --- 5: 0 True, 12 False
# Testing: 6
# --- 6: 0 True, 15 False
# Testing: 7
# --- 7: 0 True, 15 False
# Testing: 8
# --- 8: 0 True, 13 False
# Testing: 9
# --- 9: 0 True, 15 False
# Testing: 10
# --- 10: 0 True, 15 False
# Testing: 11
# --- 11: 0 True, 15 False
# Testing: 12
# --- 12: 0 True, 15 False
# Testing: 13
# --- 13: 2 True, 2 False
# Testing: 14
# --- 14: 0 True, 0 False
# Testing: 15
# --- 15: 0 True, 15 False
# Testing: 16
# --- 16: 0 True, 15 False
# Testing: 17
# --- 17: 0 True, 15 False
# Testing: 18
# --- 18: 0 True, 15 False
# Testing: 19
# --- 19: 0 True, 15 False
# Testing: 20
# --- 20: 0 True, 15 False
# Testing: 21
# --- 21: 0 True, 3 False
# Testing: 22
# --- 22: 0 True, 0 False
# Testing: 23
# --- 23: 0 True, 15 False
# Testing: 24
# --- 24: 0 True, 15 False
# Testing: 25
# --- 25: 1 True, 14 False
# Testing: 26
# --- 26: 0 True, 15 False
# Testing: 27
# --- 27: 0 True, 15 False
# Testing: 28
# --- 28: 0 True, 15 False
# Testing: 29
# --- 29: 0 True, 15 False
# Testing: 30
# --- 30: 0 True, 15 False
# Testing: 31
# --- 31: 0 True, 15 False
# Testing: 32
# --- 32: 0 True, 15 False
# Testing: 33
# --- 33: 0 True, 13 False
# Testing: 34
# --- 34: 0 True, 3 False
# Testing: 35
# --- 35: 0 True, 15 False
# Testing: 36
# --- 36: 0 True, 10 False
# Testing: 37
# --- 37: 0 True, 0 False
# Testing: 38
# --- 38: 0 True, 15 False
# Testing: 39
# --- 39: 1 True, 14 False
# Testing: 40
# --- 40: 0 True, 10 False
# Testing: 41
# --- 41: 0 True, 15 False
# Testing: 42
# --- 42: 0 True, 2 False
# Testing: 43
# --- 43: 0 True, 15 False
# Testing: 44
# --- 44: 0 True, 6 False
# Testing: 45
# --- 45: 0 True, 2 False
# Testing: 46
# --- 46: 0 True, 15 False
# Testing: 47
# --- 47: 0 True, 15 False
# Testing: 48
# --- 48: 0 True, 15 False
# Testing: 49
# --- 49: 0 True, 15 False
# Testing: 50
# --- 50: 0 True, 15 False
# Testing: 51
# --- 51: 0 True, 15 False
# Testing: 52
# --- 52: 2 True, 13 False
# Testing: 53
# --- 53: 0 True, 10 False
# Testing: 54
# --- 54: 0 True, 15 False
# Testing: 55
# --- 55: 0 True, 0 False
# Testing: 56
# --- 56: 2 True, 13 False
# Testing: 57
# --- 57: 0 True, 15 False
# Testing: 58
# --- 58: 0 True, 15 False
# Testing: 59
# --- 59: 0 True, 15 False
# Testing: 60
# --- 60: 0 True, 15 False
# Testing: 61
# --- 61: 0 True, 15 False
# Testing: 62
# --- 62: 0 True, 15 False
# Testing: 63
# --- 63: 0 True, 15 False
# Testing: 64
# --- 64: 0 True, 15 False
# Testing: 65
# --- 65: 0 True, 15 False
# Testing: 66
# --- 66: 0 True, 15 False
# Testing: 67
# --- 67: 0 True, 15 False
# Testing: 68
# --- 68: 0 True, 15 False
# Testing: 69
# --- 69: 0 True, 0 False
# Testing: 70
# --- 70: 0 True, 15 False
# Testing: 71
# --- 71: 0 True, 8 False
# Testing: 72
# --- 72: 0 True, 5 False
# Testing: 73
# --- 73: 0 True, 15 False
# Testing: 74
# --- 74: 0 True, 15 False
# Testing: 75
# --- 75: 0 True, 15 False
# Testing: 76
# --- 76: 0 True, 15 False
# Testing: 77
# --- 77: 0 True, 15 False
# Testing: 78
# --- 78: 0 True, 0 False
# Testing: 79
# --- 79: 0 True, 8 False
# Testing: 80
# --- 80: 0 True, 9 False
# Testing: 81
# --- 81: 0 True, 12 False
# Testing: 82
# --- 82: 0 True, 15 False
# Testing: 83
# --- 83: 0 True, 15 False
# Testing: 84
# --- 84: 0 True, 15 False
# Testing: 85
# --- 85: 0 True, 15 False
# Testing: 86
# --- 86: 0 True, 3 False
# Testing: 87
# --- 87: 0 True, 15 False
# Testing: 88
# --- 88: 0 True, 10 False
# Testing: 89
# --- 89: 0 True, 14 False
# Testing: 90
# --- 90: 0 True, 15 False
# Testing: 91
# --- 91: 0 True, 15 False
# Testing: 92
# --- 92: 0 True, 15 False
# Testing: 93
# --- 93: 0 True, 15 False
# Testing: 94
# --- 94: 0 True, 15 False
# Testing: 95
# --- 95: 0 True, 3 False
# Testing: 96
# --- 96: 0 True, 0 False
# Testing: 97
# --- 97: 0 True, 15 False
# Testing: 98
# --- 98: 0 True, 3 False
# Testing: 99
# --- 99: 0 True, 15 False
# Testing: 100
# --- 100: 0 True, 15 False
# Testing: 101
# --- 101: 0 True, 0 False
# Testing: 102
# --- 102: 0 True, 15 False
# Testing: 103
# --- 103: 0 True, 15 False
# Testing: 104
# --- 104: 0 True, 15 False
# Testing: 105
# --- 105: 1 True, 14 False
# Testing: 106
# --- 106: 0 True, 15 False
# Testing: 107
# --- 107: 0 True, 6 False
# Testing: 108
# --- 108: 0 True, 15 False
# Testing: 109
# --- 109: 0 True, 15 False
# Testing: 110
# --- 110: 0 True, 15 False
# Testing: 111
# --- 111: 0 True, 15 False
# Testing: 112
# --- 112: 0 True, 15 False
# Testing: 113
# --- 113: 0 True, 15 False
# Testing: 114
# --- 114: 0 True, 15 False
# Testing: 115
# --- 115: 0 True, 15 False
# Testing: 116
# --- 116: 0 True, 15 False
# Testing: 117
# --- 117: 0 True, 15 False
# Testing: 118
# --- 118: 0 True, 15 False
# Testing: 119
# --- 119: 0 True, 15 False
# Testing: 120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bf9962469e52> in <module>()
#      27     print("Testing: {}".format(ti))
#      28     image = queryBag[ti]
# ---> 29     qres=runPlaceRecognizerImg(image)
#      30     rights=0
#      31     wrongs=0
#
# <ipython-input-10-bf9962469e52> in runPlaceRecognizerImg(imageArray)
#      10     msg = bridge.cv2_to_imgmsg(imageArray, "bgr8")
#      11     server = rospy.ServiceProxy('place_recognizer', place_recognizer)
# ---> 12     placeResp = server(msg)
#      13     return placeResp.keyframeId
#      14
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/impl/tcpros_service.pyc in __call__(self, *args, **kwds)
#     440         message. This is usually a type error with one of the fields.
#     441         """
# --> 442         return self.call(*args, **kwds)
#     443
#     444     def _get_service_uri(self, request):
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/impl/tcpros_service.pyc in call(self, *args, **kwds)
#     520
#     521         try:
# --> 522             responses = transport.receive_once()
#     523             if len(responses) == 0:
#     524                 raise ServiceException("service [%s] returned no response"%self.resolved_name)
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/impl/tcpros_base.pyc in receive_once(self)
#     735                     p.read_messages(b, msg_queue, sock)
#     736                 if not msg_queue:
# --> 737                     self.stat_bytes += recv_buff(sock, b, p.buff_size)
#     738             self.stat_num_msg += len(msg_queue) #STATS
#     739             # set the _connection_header field
#
# /opt/ros/melodic/lib/python2.7/dist-packages/rospy/impl/tcpros_base.pyc in recv_buff(sock, b, buff_size)
#     102     @rtype: int
#     103     """
# --> 104     d = sock.recv(buff_size)
#     105     if d:
#     106         b.write(d)
#
# KeyboardInterrupt:
